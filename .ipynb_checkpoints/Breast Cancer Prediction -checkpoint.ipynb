# %% [markdown]
# ## Predicting Breast Cancer with Maching Learning

# %% [markdown]
# ### Imports

# %%
import pandas as pd 
import numpy as np 
import seaborn as sb 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ###  Get Data

# %%
data=pd.read_csv('data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.describe().transpose()
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
data.shape
# Out:
# (569, 33)

# %%
# check if there are null values 
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# drop the 'Unamed' Column 
data.drop('Unnamed: 32',axis=1,inplace=True)
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Data Visualisation

# %%
data.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
sb.countplot(x='diagnosis',data=data)

# %%
#Get the correlation of the columns
corrMat = data.corr()
# plot the heatmap 
plt.figure(figsize=(20,20))  
sb.heatmap(corrMat, annot=True, fmt='.0%')

# %% [markdown]
# ### Relabeling the Target Column with a LabelEncoder

# %%
#Encoding categorical data values for the diagnosis column 
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
data.diagnosis= labelencoder.fit_transform(data.diagnosis.values)
data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# group by diagnosis now 
data.diagnosis.value_counts()
# see the column values were encoded to:
## 1 means patient has an M(Malignat ):  Cancer 
## 0 means  patient hasn a B(Begnin) : No Cancer
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ### Split Data into Train and Test Set

# %%
#copy the dataframe for further use 
df=data.copy()
#Features 
X=df.drop('diagnosis',axis=1)
#Labels
y=df.pop('diagnosis')
# split into train and test set 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((426, 31), (143, 31), (426,), (143,))

# %% [markdown]
# ### Training the Model and Make Predictions

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# define a Function to train all models at once 
def train_models(X_train,Y_train):
  
     #Using Logistic Regression 
    lr = LogisticRegression(random_state = 0)
    lr.fit(X_train, Y_train)
    #Using KNeighborsClassifier 
    knn = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    knn.fit(X_train, Y_train)
    #Using SVC
    svc= SVC(kernel = 'rbf', random_state = 0)
    svc.fit(X_train, Y_train)
    #Using GaussianNB 
    nb = GaussianNB()
    nb.fit(X_train, Y_train)
    #Using DecisionTreeClassifier 
    tree = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
    tree.fit(X_train, Y_train)
    #Using RandomForestClassifier method of ensemble class to use Random Forest Classification algorithm
    rfc = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
    rfc.fit(X_train, Y_train)

    return lr, knn, svc, nb, tree, rfc

# %%
# train our model now 
models = train_models(X_train,Y_train)

# %%
type(models)
# Out:
# tuple

# %%
#print model accuracy on the training data.
print('[0]Logistic Regression Training Accuracy:', models[0].score(X_train, Y_train))
print('[1]K Nearest Neighbor Training Accuracy:', models[1].score(X_train, Y_train))
print('[3]Support Vector Machine Training Accuracy:',models[2].score(X_train, Y_train))
print('[4]Gaussian Naive Bayes Training Accuracy:', models[3].score(X_train, Y_train))
print('[5]Decision Tree Classifier Training Accuracy:', models[4].score(X_train, Y_train))
print('[6]Random Forest Classifier Training Accuracy:', models[5].score(X_train, Y_train))
# Out:
# [0]Logistic Regression Training Accuracy: 0.6291079812206573
# [1]K Nearest Neighbor Training Accuracy: 0.8450704225352113
# [3]Support Vector Machine Training Accuracy: 0.6291079812206573
# [4]Gaussian Naive Bayes Training Accuracy: 0.6267605633802817
# [5]Decision Tree Classifier Training Accuracy: 1.0
# [6]Random Forest Classifier Training Accuracy: 0.9953051643192489

# %%
# we could see that the RFC Classifier has the highest training accuracy 
# let's see for the test results

# %%
dict_models={'LogReg':models[0],'KNN':models[1],'SVC':models[2],'GNB':models[3],
             'DT':models[4],'RFC':models[5]}

# %%
# show the Results 
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

for key,model in dict_models.items():
    print('Model :',key)
    #predictions 
    preds=model.predict(X_test)
    #Check precision, recall, f1-score
    print( classification_report(Y_test,preds) )
    #Another way to get the models accuracy on the test data
    print( accuracy_score(Y_test, preds))
    print('\n')
# Out:
# Model : LogReg
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77        89
#            1       0.00      0.00      0.00        54
#
#     accuracy                           0.62       143
#    macro avg       0.31      0.50      0.38       143
# weighted avg       0.39      0.62      0.48       143
#
# 0.6223776223776224
#
#
# Model : KNN
#               precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81        89
#            1       0.72      0.48      0.58        54
#
#     accuracy                           0.73       143
#    macro avg       0.73      0.68      0.69       143
# weighted avg       0.73      0.73      0.72       143
#
# 0.7342657342657343
#
#
# Model : SVC
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77        89
#            1       0.00      0.00      0.00        54
#
# ...

# %% [markdown]
# ### Submit the Results

# %%
# from the results above ,we see that the Random Forest Classifier has the highest accuracy 
# So, we will take its predictions and sbmit it
rfc=dict_models['RFC']
rfc_preds=rfc.predict(X_test)
results=pd.Series(rfc_preds)
#submit our predictions 
submission = pd.DataFrame({'Id':results.index, 'Diagnosis': results})
submission.set_index('Id',inplace=True)
submission.to_csv('breast_cancer_submission.csv', index=False)
print(" Submission  successfully saved!")
# Out:
#  Submission  successfully saved!

# %%
submission.head()
# Out:
#     Diagnosis
# Id
# 0           0
# 1           1
# 2           1
# 3           0
# 4           0
